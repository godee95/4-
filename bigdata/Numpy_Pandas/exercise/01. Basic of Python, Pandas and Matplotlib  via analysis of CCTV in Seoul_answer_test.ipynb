# %% [markdown]
# # 서울시 구별 CCTV 현황 분석하기
#
#
#
# * 서울시 각 구별 CCTV수를 파악하고, 인구대비 CCTV 비율을 파악해서 순위 비교
# * 인구대비 CCTV의 평균치를 확인하고 그로부터 CCTV가 과하게 부족한 구를 확인

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# '01. CCTV_in_Seoul.csv' 파일 읽기
CCTV_Seoul = pd.read_csv('01. CCTV_in_Seoul.csv')
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
#column명 출력

CCTV_Seoul.columns
# Out:
# Index(['구별', '소계', '2013년도 이전', '2014년', '2015년', '2016년'], dtype='object')

# %%
#값만 출력

CCTV_Seoul.values
# Out:
# array([['강남구', 2780, 1292, 430, 584, 932],
#        ['강동구', 773, 379, 99, 155, 377],
#        ['강북구', 748, 369, 120, 138, 204],
#        ['강서구', 884, 388, 258, 184, 81],
#        ['관악구', 1496, 846, 260, 390, 613],
#        ['광진구', 707, 573, 78, 53, 174],
#        ['구로구', 1561, 1142, 173, 246, 323],
#        ['금천구', 1015, 674, 51, 269, 354],
#        ['노원구', 1265, 542, 57, 451, 516],
#        ['도봉구', 485, 238, 159, 42, 386],
#        ['동대문구', 1294, 1070, 23, 198, 579],
#        ['동작구', 1091, 544, 341, 103, 314],
#        ['마포구', 574, 314, 118, 169, 379],
#        ['서대문구', 962, 844, 50, 68, 292],
#        ['서초구', 1930, 1406, 157, 336, 398],
#        ['성동구', 1062, 730, 91, 241, 265],
#        ['성북구', 1464, 1009, 78, 360, 204],
#        ['송파구', 618, 529, 21, 68, 463],
#        ['양천구', 2034, 1843, 142, 30, 467],
#        ['영등포구', 904, 495, 214, 195, 373],
#        ['용산구', 1624, 1368, 218, 112, 398],
#        ['은평구', 1873, 1138, 224, 278, 468],
#        ['종로구', 1002, 464, 314, 211, 630],
# ...

# %%
CCTV_Seoul.columns[0]
# Out:
# '기관명'

# %%
# 칼럼명 :'기관명' -> '구별' 수정 rename

# CCTV_Seoul=CCTV_Seoul.rename(columns = {'기관명':'구별'})
CCTV_Seoul.rename(columns = {'기관명':'구별'}, inplace=True)
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %% [markdown]
# ##  엑셀파일 읽기 - 서울시 인구현황

# %%
# 01. population_in_Seoul.xls 파일 열기
pop_Seoul = pd.read_excel('01. population_in_Seoul.xls')
pop_Seoul.head()
# Out:
#          기간  자치구       세대        인구     인구.1     인구.2     인구.3     인구.4  \
# 0        기간  자치구       세대        합계       합계       합계      한국인      한국인
# 1        기간  자치구       세대         계       남자       여자        계       남자
# 2  2017.1/4   합계  4202888  10197604  5000005  5197599  9926968  4871560
# 3  2017.1/4  종로구    72654    162820    79675    83145   153589    75611
# 4  2017.1/4   중구    59481    133240    65790    67450   124312    61656
#
#       인구.5    인구.6    인구.7    인구.8  세대당인구  65세이상고령자
# 0      한국인   등록외국인   등록외국인   등록외국인  세대당인구  65세이상고령자
# 1       여자       계      남자      여자  세대당인구  65세이상고령자
# 2  5055408  270636  128445  142191   2.36   1321458
# 3    77978    9231    4064    5167   2.11     25425
# 4    62656    8928    4134    4794   2.09     20764

# %%
pop_Seoul = pd.read_excel('C:/Users/user/Desktop/bigdata/Numpy_Pandas/01. population_in_Seoul.xls', 
                          header = 2, 
                          usecols = 'B, D, G, J, N', 
                          encoding='utf-8')
pop_Seoul.head()
# Out:
#    자치구           계        계.1       계.2   65세이상고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
# 칼럼명 수정

# pop_Seoul = pop_Seoul.rename(columns={'자치구':'구별'})
pop_Seoul.columns = ['구별','인구수','한국인','외국인','고령자']
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %% [markdown]
# #  CCTV 데이터 파악하기

# %%
CCTV_Seoul.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  2780       1292    430    584    932
# 1  강동구   773        379     99    155    377
# 2  강북구   748        369    120    138    204
# 3  강서구   884        388    258    184     81
# 4  관악구  1496        846    260    390    613

# %%
# 소계를 기준으로 오름차순 정렬

CCTV_Seoul.sort_values("소계", ascending = True).head(10)
# Out:
#       구별   소계  2013년도 이전  2014년  2015년  2016년
# 9    도봉구  485        238    159     42    386
# 12   마포구  574        314    118    169    379
# 17   송파구  618        529     21     68    463
# 24   중랑구  660        509    121    177    109
# 23    중구  671        413    190     72    348
# 5    광진구  707        573     78     53    174
# 2    강북구  748        369    120    138    204
# 1    강동구  773        379     99    155    377
# 3    강서구  884        388    258    184     81
# 19  영등포구  904        495    214    195    373

# %%
# 소계를 중심으로 내림차순 정렬

CCTV_Seoul.sort_values("소계", ascending = False).head(10)
# Out:
#       구별    소계  2013년도 이전  2014년  2015년  2016년
# 0    강남구  2780       1292    430    584    932
# 18   양천구  2034       1843    142     30    467
# 14   서초구  1930       1406    157    336    398
# 21   은평구  1873       1138    224    278    468
# 20   용산구  1624       1368    218    112    398
# 6    구로구  1561       1142    173    246    323
# 4    관악구  1496        846    260    390    613
# 16   성북구  1464       1009     78    360    204
# 10  동대문구  1294       1070     23    198    579
# 8    노원구  1265        542     57    451    516

# %%
# 16년 증가율 구하기

CCTV_Seoul['2016년 증가율']=(((CCTV_Seoul["2016년"]-CCTV_Seoul["2015년"])/CCTV_Seoul["2015년"])*100)
CCTV_Seoul.head()
# Out:
#     구별    소계  2013년도 이전  2014년  2015년  2016년   2016년 증가율
# 0  강남구  2780       1292    430    584    932   59.589041
# 1  강동구   773        379     99    155    377  143.225806
# 2  강북구   748        369    120    138    204   47.826087
# 3  강서구   884        388    258    184     81  -55.978261
# 4  관악구  1496        846    260    390    613   57.179487

# %% [markdown]
# #  서울시 인구 데이터 파악하기

# %%
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
# 첫번째 row 삭제, 원본데이터 반영

pop_Seoul.drop(0).head()
# Out:
#     구별       인구수       한국인      외국인      고령자
# 1  종로구  162820.0  153589.0   9231.0  25425.0
# 2   중구  133240.0  124312.0   8928.0  20764.0
# 3  용산구  244203.0  229456.0  14747.0  36231.0
# 4  성동구  311244.0  303380.0   7864.0  39997.0
# 5  광진구  372164.0  357211.0  14953.0  42214.0

# %%
# 구별 칼럼의 unique값 구하기

pop_Seoul["구별"].unique()
# Out:
# array(['합계', '종로구', '중구', '용산구', '성동구', '광진구', '동대문구', '중랑구', '성북구',
#        '강북구', '도봉구', '노원구', '은평구', '서대문구', '마포구', '양천구', '강서구', '구로구',
#        '금천구', '영등포구', '동작구', '관악구', '서초구', '강남구', '송파구', '강동구', nan],
#       dtype=object)

# %%
# '구별'칼럼에서 결측치가 있는 row구하기
# isnull 값이 있는것만 True
# 26 번째 데이터가 결축치가 있는 row임

pop_Seoul[pop_Seoul['구별'].isnull()]
# Out:
#      구별  인구수  한국인  외국인  고령자
# 26  NaN  NaN  NaN  NaN  NaN

# %%
# '구별'칼럼에서 결측치가 있는 row 삭제하기
# dropna nan값인 행 삭제
# 또는 drop(26)으로 삭제해줌
pop_Seoul.dropna(axis=0, inplace = True)
pop_Seoul
# Out:
#       구별         인구수        한국인       외국인        고령자
# 0     합계  10197604.0  9926968.0  270636.0  1321458.0
# 1    종로구    162820.0   153589.0    9231.0    25425.0
# 2     중구    133240.0   124312.0    8928.0    20764.0
# 3    용산구    244203.0   229456.0   14747.0    36231.0
# 4    성동구    311244.0   303380.0    7864.0    39997.0
# 5    광진구    372164.0   357211.0   14953.0    42214.0
# 6   동대문구    369496.0   354079.0   15417.0    54173.0
# 7    중랑구    414503.0   409882.0    4621.0    56774.0
# 8    성북구    461260.0   449773.0   11487.0    64692.0
# 9    강북구    330192.0   326686.0    3506.0    54813.0
# 10   도봉구    348646.0   346629.0    2017.0    51312.0
# 11   노원구    569384.0   565565.0    3819.0    71941.0
# 12   은평구    494388.0   489943.0    4445.0    72334.0
# 13  서대문구    327163.0   314982.0   12181.0    48161.0
# 14   마포구    389649.0   378566.0   11083.0    48765.0
# 15   양천구    479978.0   475949.0    4029.0    52975.0
# 16   강서구    603772.0   597248.0    6524.0    72548.0
# ...

# %%
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0
# 1  종로구    162820.0   153589.0    9231.0    25425.0
# 2   중구    133240.0   124312.0    8928.0    20764.0
# 3  용산구    244203.0   229456.0   14747.0    36231.0
# 4  성동구    311244.0   303380.0    7864.0    39997.0

# %%
# 외국인 비율
pop_Seoul['외국인 비율']=((pop_Seoul["외국인"]/pop_Seoul["인구수"])*100)
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자    외국인 비율
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0  2.653918
# 1  종로구    162820.0   153589.0    9231.0    25425.0  5.669451
# 2   중구    133240.0   124312.0    8928.0    20764.0  6.700690
# 3  용산구    244203.0   229456.0   14747.0    36231.0  6.038828
# 4  성동구    311244.0   303380.0    7864.0    39997.0  2.526635

# %%
# 고령자 비율
pop_Seoul['고령자 비율']=((pop_Seoul["고령자"]/pop_Seoul["인구수"])*100)
pop_Seoul.head()
# Out:
#     구별         인구수        한국인       외국인        고령자    외국인 비율     고령자 비율
# 0   합계  10197604.0  9926968.0  270636.0  1321458.0  2.653918  12.958515
# 1  종로구    162820.0   153589.0    9231.0    25425.0  5.669451  15.615404
# 2   중구    133240.0   124312.0    8928.0    20764.0  6.700690  15.583909
# 3  용산구    244203.0   229456.0   14747.0    36231.0  6.038828  14.836427
# 4  성동구    311244.0   303380.0    7864.0    39997.0  2.526635  12.850689

# %%
# 구별 외국인 비율/ 고령자 비율 구하라

# %%
# 인구수 기준 내림차순 정렬

pop_Seoul.sort_values('인구수', ascending=False).head()
# Out:
#      구별         인구수        한국인       외국인        고령자    외국인 비율     고령자 비율
# 0    합계  10197604.0  9926968.0  270636.0  1321458.0  2.653918  12.958515
# 24  송파구    667483.0   660584.0    6899.0    72506.0  1.033584  10.862599
# 16  강서구    603772.0   597248.0    6524.0    72548.0  1.080540  12.015794
# 23  강남구    570500.0   565550.0    4950.0    63167.0  0.867660  11.072217
# 11  노원구    569384.0   565565.0    3819.0    71941.0  0.670725  12.634883

# %%
# 외국인수 기준 내림차순 정렬

pop_Seoul.sort_values('인구수', ascending=False).head()
# Out:
#      구별         인구수        한국인       외국인        고령자    외국인 비율     고령자 비율
# 0    합계  10197604.0  9926968.0  270636.0  1321458.0  2.653918  12.958515
# 24  송파구    667483.0   660584.0    6899.0    72506.0  1.033584  10.862599
# 16  강서구    603772.0   597248.0    6524.0    72548.0  1.080540  12.015794
# 23  강남구    570500.0   565550.0    4950.0    63167.0  0.867660  11.072217
# 11  노원구    569384.0   565565.0    3819.0    71941.0  0.670725  12.634883

# %%
pop_Seoul.sort_values('외국인 비율', ascending=False).head(5)
# Out:
#       구별       인구수       한국인      외국인      고령자    외국인 비율     고령자 비율
# 19  영등포구  402985.0  368072.0  34913.0  52413.0  8.663598  13.006191
# 18   금천구  255082.0  236353.0  18729.0  32970.0  7.342345  12.925255
# 17   구로구  447874.0  416487.0  31387.0  56833.0  7.007998  12.689506
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427

# %%
pop_Seoul.sort_values('고령자', ascending=False).head(5)
# Out:
#      구별         인구수        한국인       외국인        고령자    외국인 비율     고령자 비율
# 0    합계  10197604.0  9926968.0  270636.0  1321458.0  2.653918  12.958515
# 16  강서구    603772.0   597248.0    6524.0    72548.0  1.080540  12.015794
# 24  송파구    667483.0   660584.0    6899.0    72506.0  1.033584  10.862599
# 12  은평구    494388.0   489943.0    4445.0    72334.0  0.899091  14.631019
# 11  노원구    569384.0   565565.0    3819.0    71941.0  0.670725  12.634883

# %%
pop_Seoul.sort_values('고령자 비율', ascending=False).head(5)
# Out:
#       구별       인구수       한국인      외국인      고령자    외국인 비율     고령자 비율
# 9    강북구  330192.0  326686.0   3506.0  54813.0  1.061806  16.600342
# 1    종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404
# 2     중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909
# 3    용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427
# 13  서대문구  327163.0  314982.0  12181.0  48161.0  3.723221  14.720797

# %% [markdown]
# #  CCTV 데이터와 인구 데이터 합치고 분석하기

# %%
# '구별'칼럼을 기준으로 cctv데이터와 인구데이터를 합하기

seoul_df=pd.merge(pop_Seoul, CCTV_Seoul, on = '구별')
seoul_df.head()
# Out:
#     구별       인구수       한국인      외국인      고령자    외국인 비율     고령자 비율    소계  \
# 0  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404  1002
# 1   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909   671
# 2  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427  1624
# 3  성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689  1062
# 4  광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849   707
#
#    2013년도 이전  2014년  2015년  2016년   2016년 증가율
# 0        464    314    211    630  198.578199
# 1        413    190     72    348  383.333333
# 2       1368    218    112    398  255.357143
# 3        730     91    241    265    9.958506
# 4        573     78     53    174  228.301887

# %%
# 2013년도 이전, 2014년, 2015년, 2016년 칼럼 삭제
# seoul_df.drop()

seoul_df.drop(['2013년도 이전','2014년','2015년','2016년'], axis=1, inplace=True)

# %%
seoul_df.head()
# Out:
#     구별       인구수       한국인      외국인      고령자    외국인 비율     고령자 비율    소계  \
# 0  종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404  1002
# 1   중구  133240.0  124312.0   8928.0  20764.0  6.700690  15.583909   671
# 2  용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427  1624
# 3  성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689  1062
# 4  광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849   707
#
#     2016년 증가율
# 0  198.578199
# 1  383.333333
# 2  255.357143
# 3    9.958506
# 4  228.301887

# %%
# '구별' 칼럼을 인덱스로 설정

seoul_df.set_index('구별', inplace=True)
seoul_df.head()
# Out:
#           인구수       한국인      외국인      고령자    외국인 비율     고령자 비율    소계  \
# 구별
# 종로구  162820.0  153589.0   9231.0  25425.0  5.669451  15.615404  1002
# 중구   133240.0  124312.0   8928.0  20764.0  6.700690  15.583909   671
# 용산구  244203.0  229456.0  14747.0  36231.0  6.038828  14.836427  1624
# 성동구  311244.0  303380.0   7864.0  39997.0  2.526635  12.850689  1062
# 광진구  372164.0  357211.0  14953.0  42214.0  4.017852  11.342849   707
#
#       2016년 증가율
# 구별
# 종로구  198.578199
# 중구   383.333333
# 용산구  255.357143
# 성동구    9.958506
# 광진구  228.301887

# %%
# 고령자 비율과 소계의 상관계수
# corrcoef 표로 출력

np.corrcoef(seoul_df['고령자 비율'],seoul_df['소계'])
# Out:
# array([[ 1.        , -0.28078554],
#        [-0.28078554,  1.        ]])

# %%
# 외국인 비율과 소계의 상관계수

np.corrcoef(seoul_df['외국인 비율'],seoul_df['소계'])
# Out:
# array([[ 1.        , -0.13607433],
#        [-0.13607433,  1.        ]])

# %%
# 인구수와 소계의 상관계수

np.corrcoef(seoul_df['인구수'],seoul_df['소계'])
# Out:
# array([[1.        , 0.30634228],
#        [0.30634228, 1.        ]])

# %% [markdown]
# #  CCTV와 인구현황 그래프로 분석하기

# %%
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
data_result.head()

# %%
# '소계' 칼럼을 기준으로 수평 바챠트

# %%
# '소계'칼럼을 내림차순 정렬 후 수평 바챠트

# %%
# 1인당 CCTV비율 정렬후 수평 바챠트

# %%
# '인구수'와 '소계'의 분포도 그리기

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)
fp1

# %%
f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_result['인구수'], data_result['소계'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')
plt.xlabel('인구수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %% [markdown]
# #  조금더 설득력 있는 자료 만들기

# %%
fp1 = np.polyfit(data_result['인구수'], data_result['소계'], 1)

f1 = np.poly1d(fp1)
fx = np.linspace(100000, 700000, 100)

data_result['오차'] = np.abs(data_result['소계'] - f1(data_result['인구수']))

df_sort = data_result.sort_values(by='오차', ascending=False)
df_sort.head()

# %%
plt.figure(figsize=(14,10))
plt.scatter(data_result['인구수'], data_result['소계'], 
            c=data_result['오차'], s=50)
plt.plot(fx, f1(fx), ls='dashed', lw=3, color='g')

for n in range(10):
    plt.text(df_sort['인구수'][n]*1.02, df_sort['소계'][n]*0.98, 
             df_sort.index[n], fontsize=15)
    
plt.xlabel('인구수')
plt.ylabel('인구당비율')
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# * 서울시에서 다른 구와 비교했을 때, 강남구, 양천구, 서초구, 은평구는 CCTV가 많지만,
# * 송파구, 강서구, 도봉구, 마포구는 다른 구에 비해 CCTV 비율이 낮다
